# %%
# %pip install stomp.py confluent-kafka prometheus_client
# Run this cell once to install dependencies on the cluster
# %pip install stomp.py confluent-kafka prometheus_client

# %%
# api_key = dbutils.secrets.get(scope="kafka-secrets", key="confluent-api-key")
# api_secret = dbutils.secrets.get(scope="kafka-secrets", key="confluent-api-secret")
